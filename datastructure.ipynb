# %% [markdown]
# contacts_list=dict(ahmed=01023223176 , mahmed : 0105276123 , sayed= 011527766123)
#
# print(contacts_list.items())
#
# print(contacts_list[ahmed])

# %%
ahmed=dict(math=5,history=7,English=9)
mohamed=dict(math=10,history=8,english=7)
def ahmed(*args):
     total=0
for num in args :
        total+=num
 return total
print (sum_all(5,7,9))
# Out:
#   File <tokenize>:7
#     return total
#     ^
# IndentationError: unindent does not match any outer indentation level
