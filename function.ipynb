# %%
def is_prime(number):
    if number<2:
        return false 
        for i in rane(2,  int(math.sqrt(number))+1):
            if number % i ==0:
                return false
    return true

# %%
def calculator (a, b, ):
    return a * b
result=calculator(15 , 50)
print(result)
# Out:
# 750
